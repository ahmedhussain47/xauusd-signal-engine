# %% [markdown]
# # 01 Data Collection
#
# Downloads daily OHLCV data for a small model-focused benchmark universe.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
print('Project root:', PROJECT_ROOT)
# Out:
# Project root: c:\Users\user\OneDrive\Desktop\Praktikum\Final-Project\new_equity_forecasting_project

# %%
from src.config import TICKERS, START_DATE, END_DATE, DATA_RAW_DIR
from src.data_utils import download_ohlcv

summary = download_ohlcv(TICKERS, DATA_RAW_DIR, START_DATE, END_DATE)
summary
# Out:
# ...
#   saved C:\Users\user\OneDrive\Desktop\Praktikum\Final-Project\new_equity_forecasting_project\data\raw\AAPL.csv (1838 rows)
# ...
#   saved C:\Users\user\OneDrive\Desktop\Praktikum\Final-Project\new_equity_forecasting_project\data\raw\MSFT.csv (1838 rows)
# ...
#   saved C:\Users\user\OneDrive\Desktop\Praktikum\Final-Project\new_equity_forecasting_project\data\raw\GOOGL.csv (1838 rows)
# ...
#   saved C:\Users\user\OneDrive\Desktop\Praktikum\Final-Project\new_equity_forecasting_project\data\raw\AMZN.csv (1838 rows)
# ...
#   saved C:\Users\user\OneDrive\Desktop\Praktikum\Final-Project\new_equity_forecasting_project\data\raw\META.csv (1838 rows)
# ...
#   saved C:\Users\user\OneDrive\Desktop\Praktikum\Final-Project\new_equity_forecasting_project\data\raw\NVDA.csv (1838 rows)
# ...
#   saved C:\Users\user\OneDrive\Desktop\Praktikum\Final-Project\new_equity_forecasting_project\data\raw\TSLA.csv (1838 rows)
# ...

# %%
print(summary)
print('Saved raw files to:', DATA_RAW_DIR)
# Out:
#    Ticker  rows status
# 0    AAPL  1838     ok
# 1    MSFT  1838     ok
# 2   GOOGL  1838     ok
# 3    AMZN  1838     ok
# 4    META  1838     ok
# 5    NVDA  1838     ok
# 6    TSLA  1838     ok
# 7     JPM  1838     ok
# 8     XOM  1838     ok
# 9     LLY  1838     ok
# 10    UNH  1838     ok
# 11    JNJ  1838     ok
# 12      V  1838     ok
# 13     PG  1838     ok
# 14     MA  1838     ok
# 15     HD  1838     ok
# 16   COST  1838     ok
# 17   ABBV  1838     ok
# 18    BAC  1838     ok
# 19     KO  1838     ok
# 20    PEP  1838     ok
# 21   AVGO  1838     ok
# 22    WMT  1838     ok
# 23    MRK  1838     ok
# 24   ADBE  1838     ok
# 25    CRM  1838     ok
# 26   NFLX  1838     ok
# 27    AMD  1838     ok
# 28   INTC  1838     ok
# 29   CSCO  1838     ok
# 30    TMO  1838     ok
# 31    MCD  1838     ok
# 32    ABT  1838     ok
# 33    DIS  1838     ok
# 34    WFC  1838     ok
# 35    PFE  1838     ok
# 36    CVX  1838     ok
# 37   ORCL  1838     ok
# 38    ACN  1838     ok
# ...
